# %%
data=[]           # for libraryan
data1=[]          # for students
books=["c","c++","python","java","css","sql"]
books1=["c","c++","python","java","css","sql"]

# %%
from datetime import date
def library():
    
    def admine_panel():      #admine details
        
        def get_user_signup():
            print("Welcome! Please sign up.\n")
            email = input("Enter your email: ")
            password = input("Enter your password: ")
            return email, password


        def validate_email(email):
            if " " not in email and email.endswith("@gmail.com"):
                return True
            else:
                return False
        def validate_password(password):
            lower = 0
            upper = 0
            number = 0
            special = 0

            for i in password:
                if i.islower():
                    lower += 1
                elif i.isupper():
                    upper += 1
                elif i.isdigit():
                    number += 1
                elif not (i.isidentifier()):
               # elif i in "~!@#$%^&*()_+<>?":
                    special += 1

            if lower>=1 and upper>=1 and number>=1 and special>=1 and len(password)>=8:
                return True 
            else:
                return False

        def create_account(email, password):
            print("Account created successfully!")
            data.append([email,password])
        def signup():
            while True:
                email, password = get_user_signup()

                if validate_email(email):
                    if validate_password(password):
                        create_account(email, password)
                        break
                    else:
                        print("invalid pasword. please enter a velid password")
                else:
                    print("Invalid email. Please enter a valid email address.")
                    
        def login():
            email=input("enter your email :")
            password=input("enter your password :")
            for i in data:
                if email==i[0]:
                    if password==i[1]:
                        print("login successfully")
                    else:
                        print("your password is Rong")
                else:
                    print("error")
                    break
                    
                def book_details():                                 # book details

                    def all_book():
                        print("all book details:\n")
                        for i in range(1,len(books)+1):
                            print(f"{i}. {books[i-1]}")
                        while True:
                            choice=input("enter your choice :")
                            if choice=="1":
                                print("c")
                            elif choice=="2":
                                print("c++")
                            elif choice=="3":
                                print("python")
                            elif choice=="4":
                                print("java")
                            elif choice=="5":
                                print("css")
                            elif choice=="6":
                                print("sql")
                            else:
                                print("invelid choice")
                                break

                    def particular_book():
                        while True:
                            book_name=input("enter your book name :")
                            if book_name in books:
                                print(book_name)
                            else:
                                print("sorry, this book is not found\n")
                                break

                    while True:
                        print("book details \n")
                        print("1. all books\n2. particular books\n")
                        choice=input("enter your choice 1 or 2 :")
                        if choice=="1":
                            all_book()
                        elif choice=="2":
                            particular_book()
                        else:
                            print("invelid choice")
                            break                                      # book details end

                def student_details():                                       # student details start
                    students={"ankit saini":{"Fathe's Name":"shishram saini","Mother's Name":"maya devi","mob":7877428069},
                        "deepak dumawat":{"Fathe's Name":"sagarnal kumawat","Mother's Name":"pata nhi","mob":9928769840},
                        "nitesh saini":{"Fathe's Name":"ramesh chand","Mother's Name":"manju devi","mob":9985674634},
                        "yogesh saini":{"Fathe's Name":"shishram saini","Mother's Name":"maya devi","mob":9549145596}}

                    def all_student():
                        print("student's list\n")
                        for i in students.keys():
                            print(i,students[i])

                    def particular():
                        while True:
                            name=input("enter student name :")
                            if name in students:
                                print(students[name])
                            else:
                                print(name, "is not found\n")
                                break

                    while True:
                        print("students details :\n")
                        print("1. all students\n2. particular students\n")
                        choice=input("enter your choice 1 or 2 :\n")
                        if choice=="1":
                            all_student()
                        elif choice=="2":
                            particular()
                        else:
                            print("invelid choice")
                            break
                                           # student details end
                while True:
                    print("chouse your choice : ")
                    print("1. book details\n2. student details\n")
                    choice=input("enter your choice : ")
                    if choice=="1":
                        book_details()
                    elif choice=="2":
                        student_details()
                    else:
                        print("invelid choice")
                        break

        
        while True:
            print("chouse any one choice :\n")
            print("1. signup\n2. login\n")
            choice=input("enter your choice : ")
            if choice=="1":
                signup()
            elif choice=="2":
                login()
            else:
                print("invelid choice")
                break
    
    def student_panel():    # student panel
        def get_user_signup():
            print("Welcome! Please sign up.\n")
            email = input("Enter your email: ")
            password = input("Enter your password: ")
            return email, password


        def validate_email(email):
            if " " not in email and email.endswith("@gmail.com"):
                return True
            else:
                return False
        def validate_password(password):
            lower = 0
            upper = 0
            number = 0
            special = 0

            for i in password:
                if i.islower():
                    lower += 1
                elif i.isupper():
                    upper += 1
                elif i.isdigit():
                    number += 1
                elif not (i.isidentifier()):
               # elif i in "~!@#$%^&*()_+<>?":
                    special += 1

            if lower>=1 and upper>=1 and number>=1 and special>=1 and len(password)>=8:
                return True 
            else:
                return False

        def create_account(email, password):
            print("Account created successfully!")
            data1.append([email,password])
        def signup_student():
            while True:
                email, password = get_user_signup()

                if validate_email(email):
                    if validate_password(password):
                        create_account(email, password)
                        break
                    else:
                        print("Invalid password. Please enter a valid password.")
                else:
                    print("Invalid email. Please enter a valid email address.")

        def login_student():
            email=input("enter your email :")
            password=input("enter your password :")
            for i in data1:
                if email==i[0]:
                    if password==i[1]:
                        print("login successfully")
                    else:
                        print("your password is Rong")
                else:
                    print("error")
                    break
                    
            def book_search():
                bookss={"c":{"author":"ankit"},
                      "python":{"author":"tarun"},
                      "java":{"author":"shubham"},
                      "sql":{"author":"nitesh"},
                      "c++":{"author":"deepak"},
                       "css":{"author":"kanu"}}
                def Name():
                    name=input("enter your book name :")
                    for i in bookss.keys():
                        if name==i:
                            print(name)


                def author():
                    author_name=input("enter your book name :")
                    for i in bookss.keys():
                        if author_name == bookss[i]["author"]:
                            print(bookss[i])

                while True:
                    print("search books \n")
                    print("1. by name\n2. by author name\n")
                    choice=input("enter your choice : ")
                    if choice=="1":
                        Name()
                    elif choice=="2":
                        author()
                    else:
                        print("invelid choice")
                        break
            
            def Return():
                book_name=input("enter your book naame :")
                if book_name in books1 and book_name not in books:
                    books.append(book_name)
                    print("thanks for return book")
                    today = date.today()
                    print("Today's date:", today)
                else:
                    print("sorry this book is not hamari")


                 
            def issue_book():
                book_name=input("enter book name :")
                while True:
                    if book_name in books:
                        books.remove(book_name)
                        print("book issued\nthanks for visit our library")
                        today = date.today()
                        print("Today's date:", today)
                        break
                    else:
                        print("sorry, this book is not in our library")
                        break
            
            while True:
                print("chouse your choice \n")
                print("1. book search \n2. issue book \n3. return book\n")
                choice=input("enter your choice ")
                if choice=="1":
                    book_search()
                elif choice=="2":
                    issue_book()
                elif choice=="3":
                    Return()
                else:
                    print("invelid choice")
                    break
                
                
        while True:
            print("chouse your choice\n")
            print("1. signup\n2. login\n")
            choice=input("enter your choice : ")
            if choice=="1":
                signup_student()
            elif choice=="2":
                login_student()
            else:
                print("invelid choice")
                break
    
    while True:
        print("please chouse one choice \n")
        print("1. Admine panel\n2. student panel\n")
        choice=input("enter your choice :")
        if choice=="1":
            admine_panel()
        elif choice=="2":
            student_panel()
        else:
            print("invelid choice")
            break
            
library()
# Out:
# please chouse one choice
#
# 1. Admine panel
# 2. student panel
#
# enter your choice :1
# chouse any one choice :
#
# 1. signup
# 2. login
#
# enter your choice : 2
# enter your email :ankit.kanusaini@gmail.com
# enter your password :1234567777
# chouse any one choice :
#
# 1. signup
# 2. login
#
# enter your choice : 1
# Welcome! Please sign up.
#
# Enter your email: ankit.kanusaini@gmail.com
# Enter your password: anKit@123
# Account created successfully!
# chouse any one choice :
#
# 1. signup
# 2. login
#
# enter your choice : 2
# enter your email :ankit.kanusaini@gmail.com
# enter your password :anKit@123
# login successfully
# chouse your choice :
# 1. book details
# 2. student details
#
# enter your choice : 1
# book details
#
# 1. all books
# 2. particular books
#
# enter your choice 1 or 2 :1
# all book details:
#
# 1. c
# 2. c++
# 3. python
# 4. java
# 5. css
# 6. sql
# enter your choice :7
# invelid choice
# book details
#
# 1. all books
# 2. particular books
#
# ...
